# %%
titanic = pd.read_csv("titanic.csv")

grouped = titanic.groupby("Pclass").agg(
    AverageAge=("Age", "mean"),
    TotalFare=("Fare", "sum"),
    PassengerCount=("PassengerId", "count")
).reset_index()

# %%
multi_grouped = movies.groupby(["color", "director_name"]).agg(
    TotalCritics=("num_critic_for_reviews", "sum"),
    AvgDuration=("duration", "mean")
).reset_index()

# %%
flights = pd.read_csv("flights.csv")

nested_group = flights.groupby(["Year", "Month"]).agg(
    TotalFlights=("FlightNum", "count"),
    AvgArrDelay=("ArrDelay", "mean"),
    MaxDepDelay=("DepDelay", "max")
).reset_index()
